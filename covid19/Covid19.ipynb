# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
covid = pd.read_csv("../csv/covid.csv")

# %%
covid.head()
# Out:
#   iso_code location        date  total_cases  new_cases  total_deaths  \
# 0      ABW    Aruba  2020-03-13            2          2             0
# 1      ABW    Aruba  2020-03-20            4          2             0
# 2      ABW    Aruba  2020-03-24           12          8             0
# 3      ABW    Aruba  2020-03-25           17          5             0
# 4      ABW    Aruba  2020-03-26           19          2             0
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0                   18.733                 18.733
# 1           0                   37.465                 18.733
# 2           0                  112.395                 74.930
# 3           0                  159.227                 46.831
# 4           0                  177.959                 18.733
#
#    total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 0                       0.0  ...         13.085          7.452
# ...

# %%
covid.tail()
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 19491      NaN  International  2020-02-28          705          0
# 19492      NaN  International  2020-02-29          705          0
# 19493      NaN  International  2020-03-01          705          0
# 19494      NaN  International  2020-03-02          705          0
# 19495      NaN  International  2020-03-10          696         -9
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 19491             4           0                      NaN
# 19492             6           2                      NaN
# 19493             6           0                      NaN
# 19494             6           0                      NaN
# 19495             7           1                      NaN
#
#        new_cases_per_million  total_deaths_per_million  ...  aged_65_older  \
# 19491                    NaN                       NaN  ...            NaN
# ...

# %%
covid.shape
# Out:
# (19496, 32)

# %%
covid.ndim
# Out:
# 2

# %%
covid.columns
# Out:
# Index(['iso_code', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_units',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cvd_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_100k'],
#       dtype='object')

# %%
covid["location"].value_counts()
# Out:
# Netherlands       146
# Italy             146
# Belarus           146
# Czech Republic    146
# China             146
#                  ...
# Yemen              45
# Western Sahara     29
# Tajikistan         24
# Comoros            23
# Lesotho            10
# Name: location, Length: 212, dtype: int64

# %%
covid.describe(include="O")
# Out:
#        iso_code     location        date      tests_units
# count     19432        19496       19496             6229
# unique      211          212         146                5
# top         SGP  Netherlands  2020-05-18  tests performed
# freq        146          146         211             2462

# %%
covid.describe()
# Out:
#         total_cases      new_cases   total_deaths    new_deaths  \
# count  1.949600e+04   19496.000000   19496.000000  19496.000000
# mean   1.752634e+04     540.990152    1162.475739     35.055601
# std    1.808525e+05    4858.071697   12377.578661    334.755956
# min    0.000000e+00   -2461.000000       0.000000      0.000000
# 25%    5.000000e+00       0.000000       0.000000      0.000000
# 50%    8.400000e+01       2.000000       1.000000      0.000000
# 75%    1.135250e+03      43.000000      24.000000      1.000000
# max    5.273572e+06  107909.000000  341722.000000  10520.000000
#
#        total_cases_per_million  new_cases_per_million  \
# count             19119.000000           19119.000000
# mean                499.008529              13.312513
# std                1458.509832              63.749619
# min                   0.000000            -265.189000
# 25%                   0.593000               0.000000
# 50%                  26.720000               0.246000
# ...

# %%
#Check if columns have null values
covid.isna().any()
# Out:
# iso_code                            True
# location                           False
# date                               False
# total_cases                        False
# new_cases                          False
# total_deaths                       False
# new_deaths                         False
# total_cases_per_million             True
# new_cases_per_million               True
# total_deaths_per_million            True
# new_deaths_per_million              True
# total_tests                         True
# new_tests                           True
# total_tests_per_thousand            True
# new_tests_per_thousand              True
# new_tests_smoothed                  True
# new_tests_smoothed_per_thousand     True
# tests_units                         True
# stringency_index                    True
# population                          True
# population_density                  True
# median_age                          True
# aged_65_older                       True
# ...

# %%
#Sum of null values across each column
covid.isna().sum()
# Out:
# iso_code                              64
# location                               0
# date                                   0
# total_cases                            0
# new_cases                              0
# total_deaths                           0
# new_deaths                             0
# total_cases_per_million              377
# new_cases_per_million                377
# total_deaths_per_million             377
# new_deaths_per_million               377
# total_tests                        14332
# new_tests                          14904
# total_tests_per_thousand           14332
# new_tests_per_thousand             14904
# new_tests_smoothed                 13866
# new_tests_smoothed_per_thousand    13866
# tests_units                        13267
# stringency_index                    4500
# population                            64
# population_density                   850
# median_age                          1743
# aged_65_older                       1980
# ...

# %%
#Covid cases in Inda
india_cases=covid[covid["location"] == "India"]

# %%
india_cases.describe()
# Out:
#          total_cases    new_cases  total_deaths  new_deaths  \
# count     145.000000   145.000000    145.000000  145.000000
# mean    15488.441379   909.434483    490.613793   26.668966
# std     30260.369175  1600.985833    947.597226   44.852080
# min         0.000000     0.000000      0.000000    0.000000
# 25%         3.000000     0.000000      0.000000    0.000000
# 50%        75.000000     8.000000      1.000000    0.000000
# 75%     14378.000000  1211.000000    480.000000   37.000000
# max    131868.000000  6767.000000   3867.000000  195.000000
#
#        total_cases_per_million  new_cases_per_million  \
# count               145.000000             145.000000
# mean                 11.223414               0.659028
# std                  21.927748               1.160173
# min                   0.000000               0.000000
# 25%                   0.002000               0.000000
# 50%                   0.054000               0.006000
# ...

# %%
india_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 8379 to 8523
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         145 non-null    object
#  1   location                         145 non-null    object
#  2   date                             145 non-null    object
#  3   total_cases                      145 non-null    int64
#  4   new_cases                        145 non-null    int64
#  5   total_deaths                     145 non-null    int64
#  6   new_deaths                       145 non-null    int64
#  7   total_cases_per_million          145 non-null    float64
#  8   new_cases_per_million            145 non-null    float64
#  9   total_deaths_per_million         145 non-null    float64
#  10  new_deaths_per_million           145 non-null    float64
#  11  total_tests                      60 non-null     float64
# ...

# %%
india_cases.isna().any()
# Out:
# iso_code                           False
# location                           False
# date                               False
# total_cases                        False
# new_cases                          False
# total_deaths                       False
# new_deaths                         False
# total_cases_per_million            False
# new_cases_per_million              False
# total_deaths_per_million           False
# new_deaths_per_million             False
# total_tests                         True
# new_tests                           True
# total_tests_per_thousand            True
# new_tests_per_thousand              True
# new_tests_smoothed                  True
# new_tests_smoothed_per_thousand     True
# tests_units                         True
# stringency_index                    True
# population                         False
# population_density                 False
# median_age                         False
# aged_65_older                      False
# ...

# %%
india_cases.head()
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 8379      IND    India  2019-12-31            0          0             0
# 8380      IND    India  2020-01-01            0          0             0
# 8381      IND    India  2020-01-02            0          0             0
# 8382      IND    India  2020-01-03            0          0             0
# 8383      IND    India  2020-01-04            0          0             0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8379           0                      0.0                    0.0
# 8380           0                      0.0                    0.0
# 8381           0                      0.0                    0.0
# 8382           0                      0.0                    0.0
# 8383           0                      0.0                    0.0
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# ...

# %%
india_cases.tail()
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 8519      IND    India  2020-05-20       106750       5611          3303
# 8520      IND    India  2020-05-21       112359       5609          3435
# 8521      IND    India  2020-05-22       118447       6088          3583
# 8522      IND    India  2020-05-23       125101       6654          3720
# 8523      IND    India  2020-05-24       131868       6767          3867
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8519         140                   77.355                  4.066
# 8520         132                   81.419                  4.064
# 8521         148                   85.831                  4.412
# 8522         137                   90.653                  4.822
# 8523         147                   95.556                  4.904
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# ...

# %%
india_cases["total_deaths"].sum()
# Out:
# 71139

# %%
#Total cases per day
sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x="date", y="total_cases", data=india_cases)
plt.show()

# %%
india_last_5_days = india_cases.tail()

# %%
#Total cases per day
sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x="date", y="total_cases", data=india_last_5_days)
plt.show()
